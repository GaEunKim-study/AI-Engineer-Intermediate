# %% [markdown]
# # 딥러닝에 필요한 수학

# %% [markdown]
# ## 벡터(Vector)
# - 1차원 배열 형태, 가로 벡터, 세로 벡터, 기본은 가로 벡터
# - 벡터를 구성하는 숫자를 요소라고 부르고, 요소의 수가 벡터의 차원이 됨
# - 전치(transpose, T) : 세로 벡터를 세로 벡터로, 세로 벡터를 가로 벡터로 변환

# %% [markdown]
# ### 벡터 생성

# %% [markdown]
# - np.array()를 이용하여 벡터 정의

# %%
import numpy as np

a = np.array([2, 1]) 
print(a)
print(type(a))
# Out:
# [2 1]
# <class 'numpy.ndarray'>

# %%
b = np.array([[1, 2], [3, 4]])
print(b)
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
# ### 세로 벡터로 나타내기

# %%
a = np.array([[1], [2]])
print(a)
# Out:
# [[1]
#  [2]]

# %% [markdown]
# ### 전치(transpose)
# - 변수명.T

# %%
a = np.array([[1], [2]])
print(a)
print(a.T)
# Out:
# [[1]
#  [2]]
# [[1 2]]

# %% [markdown]
# ### 벡터의 덧셈과 뺄셈
# - 각 요소를 더하는 벡터의 덧셈과 뺄셈은 a와 b를 변으로 하는 평행사변형의 "대각선을 구하는 연산"으로 해석할 수 있음

# %% [markdown]
# ![vector_opeartion.PNG](data:image/png;base64,...)

# %%
a = np.array([2, 1])
b = np.array([1, 3])

a + b
# Out:
# array([3, 4])

# %%
a = np.array([2, 1])
b = np.array([1, 3])

a - b
# Out:
# array([ 1, -2])

# %% [markdown]
# ### 스칼라의 곱셈
# - 스칼라에 벡터를 곱하면 스칼라 값이 벡터의 요소 전체에 적용됨

# %% [markdown]
# ![vector_broadcast.PNG](data:image/png;base64,...)

# %%
a = np.array([2, 1])
2*a
# Out:
# array([4, 2])

# %% [markdown]
# ### 내적(dot 연산)
# - 같은 차원을 가진 두 벡터 간의 연산, "."로 나타냄
# - 대응하는 요소들을 곱한 뒤 더한 값을 취함

# %% [markdown]
# ![vector_dot.PNG](data:image/png;base64,...)

# %%
b = np.array([1, 3])
c = np.array([4, 2])
print(b.dot(c))
# Out:
# 10

# %% [markdown]
# ### 벡터의 크기
# - 벡터의 크기는 |와 | 사이에 나타냄
# - np.linalg.norm()

# %% [markdown]
# ![vector_size.PNG](data:image/png;base64,...)

# %%
a = np.array([1, 3])
print(1**2 + 3**2)
print(np.sqrt(1**2 + 3**2))
print(np.linalg.norm(a))
# Out:
# 10
# 3.1622776601683795
# 3.1622776601683795

# %% [markdown]
# ### 합, 시그마

# %% [markdown]
# ![vector_sigma.PNG](data:image/png;base64,...)

# %% [markdown]
# ![vector_sigma22.PNG](data:image/png;base64,...)

# %% [markdown]
# - 1~1000 합을 내적으로 계산하기(for문 사용하지 않고)

# %% [markdown]
# ![vector_sigma3.PNG](data:image/png;base64,...)

# %%
import numpy as np
a = np.ones(1000)
b = np.arange(1, 1001,1)
print(a.dot(b))
# Out:
# 500500.0

# %% [markdown]
# ### 곱, 파이
# ![vector_pie.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 다항식의 미분
# - 함수의 기울기를 도출하는 방법이 '미분'
# ![mibun.PNG](data:image/png;base64,...)

# %% [markdown]
# ![mibun2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![mibun3.PNG](data:image/png;base64,...)

# %% [markdown]
# ![mibun4.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 행렬(matrix)
# - 2차원 배열, 행과 열로 구성

# %% [markdown]
# ![matrix.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 행렬의 덧셈과 뺄셈
# - 행렬의 크기가 같아야 연산 진행됨

# %% [markdown]
# ![matrix2.PNG](data:image/png;base64,...)

# %%
import numpy as np
A = np.array([[1, 2, 3], [4, 5, 6]])
B = np.array([[7, 8, 9], [10, 11, 12]])
print(A+B)
print(A-B)
# Out:
# [[ 8 10 12]
#  [14 16 18]]
# [[-6 -6 -6]
#  [-6 -6 -6]]

# %% [markdown]
# ### 스칼라의 배
# ![matrix3.PNG](data:image/png;base64,...)

# %%
A = np.array([[1, 2, 3], [4, 5, 6]])
print(2*A)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %% [markdown]
# ### 행렬의 곱
# - 1 X M 행렬과 M X 1 행렬의 곱 = 1 X 1

# %% [markdown]
# ![matrix4.PNG](data:image/png;base64,...)<img src="../images/matrix4.PNG" width=600 height=400 align=left>

# %%
import numpy as np
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
print(A.dot(B))
# Out:
# 32

# %% [markdown]
# - N X M 행렬과 M X N 행렬의 곱 = N X N

# %% [markdown]
# ![matrix5.PNG](data:image/png;base64,...)

# %%
A = np.array([[1, 2, 3], [-1, -2, -3]])
B = np.array([[4, -4], [5, -5], [6, -6]])
print(A.dot(B))
# Out:
# [[ 32 -32]
#  [-32  32]]

# %% [markdown]
# ### 전치 행렬
# - 세로 벡터를 가로 벡터로, 가로 벡터를 세로 벡터로 만드는 연산인 전치 T는 행렬로 확장할 수 있음.

# %% [markdown]
# ![matrix8.PNG](data:image/png;base64,...)

# %%
A = np.array([[1,2,3], [4,5,6]])
print(A)
print(A.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# ### 지수
# - 지수는 ‘그 수를 여러 번 곱한다’는 곱셈의 횟수에서 출발한 개념
# - 자연수뿐만 아니라 0에도, 음수에도, 실수에도 확장할 수 있음.
# - 지수 함수(exponential function)란 거듭제곱의 지수를 변수로 하고, 정의역을 실수 전체로 정의하는
#   초월함수. 로그함수의 역함

# %% [markdown]
# ![matrix11.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 로그함수
# - ‘로그 함수’는 지수 함수의 입력과 출력을 거꾸로 한 것임. 즉, 지수 함수의 역함수임.

# %% [markdown]
# ![matrix12.PNG](data:image/png;base64,...)

# %%
# 로그 함수
import matplotlib.pyplot as plt

x = np.linspace(-8, 8, 100)
y = 2**x

x2 = np.linspace (0.001, 8, 100) # np.log(0)는 에러가 되므로 0은 포함하지 않음
y2 = np.log (x2) / np.log (2) # 밑을 2로 한 log를 계산
plt.figure(figsize=(5, 5))
plt.plot(x, y, 'black', linewidth=3)
plt.plot(x2, y2, 'cornflowerblue', linewidth=3)
plt.plot(x, x, 'black', linestyle='--', linewidth=1)
plt.ylim(-8, 8)
plt.xlim(-8, 8)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 지수 함수의 미분
# ![matrix13.PNG](data:image/png;base64,...)

# %%
x = np.linspace(-4, 4, 100)
a = 2 # 여러 값으로 변환
y = a**x
dy = np.log(a)*y

plt.figure(figsize=(4, 4))
plt.plot(x, y, 'gray', linestyle='--', linewidth=3)
plt.plot(x, dy, color='black', linewidth=3)
plt.ylim(-1, 8)
plt.xlim(-4, 4)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 로그 함수의 미분
# ![matrix14.PNG](data:image/png;base64,...)

# %%
x = np.linspace(0.0001, 4, 100) # 0이하로 정의할 수 없는
y = np.log(x)
dy = 1 / x

plt.figure(figsize=(4, 4))
plt.plot(x, y, 'gray', linestyle='--', linewidth=3)
plt.plot(x, dy, color='black', linewidth=3)
plt.ylim(-8, 8)
plt.xlim(-1, 4)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 시그모이드 함수
# - 시그모이드 함수는 매끄러운 계단 같은 함수임.
# - 음에서 양의 실수를 0에서 1까지의 사이로 변환하기 때문에 확률을 나타낼 때 자주 사용함

# %% [markdown]
# ![sigmoid.PNG](data:image/png;base64,...)

# %%
# 시그모이드
x = np.linspace(-10, 10, 100)
y = 1 / (1 + np.exp(-x))

plt.figure(figsize=(4, 4))
plt.plot(x, y, 'black', linewidth=3)

plt.ylim(-1, 2)
plt.xlim(-10, 10)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 소프트맥스 함수
# - 소프트맥스 함수를 입력과 출력이 3차원이므로 그대로 그릴 수는 없음.
# - 그래서 x2만 로 고정하여 다양한 x0과 x1을 입력했을 때의 y0과 y1를 플롯함.

# %% [markdown]
# ![softmax.PNG](data:image/png;base64,...)

# %%
def softmax(x0, x1, x2):
    u = np.exp(x0) + np.exp(x1) + np.exp(x2)
    return np.exp(x0) / u, np.exp(x1) / u, np.exp(x2) / u 

# test
y = softmax(2, 1, -1)
print(np.round (y, 2)) # 소수점 2 자리로 최대한 가깝게 표시
print(np.sum (y)) # 합계를 표시
# Out:
# [0.71 0.26 0.04]
# 1.0

# %%
from mpl_toolkits.mplot3d import Axes3D

xn = 20
x0 = np.linspace(-4, 4, xn)
x1 = np.linspace(-4, 4, xn)

y = np.zeros((xn, xn, 3))
for i0 in range(xn):
    for i1 in range(xn):
        y[i1, i0] = softmax(x0[i0], x1[i1], 1)
        
xx0, xx1 = np.meshgrid(x0, x1)        
plt.figure(figsize=(8, 3))
for i in range(2):
    ax = plt.subplot(1, 2, i+1, projection='3d')
    ax.plot_surface(xx0, xx1, y[:, :, i],
                   rstride=1, cstride=1, alpha=0.3,
                   color='blue', edgecolor='black')
    ax.set_xlabel('$x_0$', fontsize=14)
    ax.set_ylabel('$x_1$', fontsize=14)
    ax.view_init(40, -125)
    
plt.show()

# %% [markdown]
# ### 소프트맥스 함수와 시그모이드 함수
# ![sfandsm.PNG](data:image/png;base64,...)
